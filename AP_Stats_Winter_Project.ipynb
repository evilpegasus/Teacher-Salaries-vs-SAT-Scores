# %% [markdown]
# <a href="https://colab.research.google.com/github/evilpegasus/APStats/blob/master/AP_Stats_Winter_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parser

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
#display 500 rows and 500 columns
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_excel('/WA_School_Personnel_2018-2019.xlsx', sheet_name='Districts A-G', usecols= [0, 2, 6])
df2 = pd.read_excel('/WA_School_Personnel_2018-2019.xlsx', sheet_name='Districts H-P', usecols= [0, 2, 6])
df3 = pd.read_excel('/WA_School_Personnel_2018-2019.xlsx', sheet_name='Districts Q-Z', usecols= [0, 2, 6])
df = df.append(df2)
df = df.append(df3)
#print
#print("Column headings:")
#print(df.columns)
print(df)
# Out:
#       School District              Duty Title  Total Salary
# 0            Aberdeen                    Aide         20104
# 1            Aberdeen                    Aide         18602
# 2            Aberdeen  Elem. Homeroom Teacher         90036
# 3            Aberdeen       Secondary Teacher         52723
# 4            Aberdeen       Secondary Teacher        103841
# ...               ...                     ...           ...
# 51414          Zillah         Office/Clerical         33965
# 51415          Zillah       Secondary Teacher         80964
# 51416          Zillah     Other School Admin.        114771
# 51417          Zillah                    Aide         20979
# 51418          Zillah  Elem. Homeroom Teacher         62261
#
# [153854 rows x 3 columns]

# %%
districts = df.groupby('School District').nunique()
print(districts)
#districts.to_excel('districts.xlsx')

#Number of rows (unique districts)
print(districts.shape[0])
# Out:
#                      School District  Duty Title  Total Salary
# School District
# Aberdeen                           1          27           560
# Adna                               1          13            85
# Almira                             1           8            25
# Anacortes                          1          27           345
# Arlington                          1          31           644
# Asotin-Anatone                     1          14           106
# Auburn                             1          29          2143
# Bainbridge                         1          29           546
# Battle Ground                      1          32          1581
# Bellevue                           1          30          2843
# Bellingham                         1          31          1664
# Benge                              1           4             5
# Bethel                             1          32          2571
# Bickleton                          1           9            24
# ...

# %%
sat_df = pd.read_excel('/WA _District_SAT_2019.xlsx', usecols= [0, 10])
print(sat_df)
#print(sat_df.shape[0])
# Out:
#          School District  Total Score Mean
# 0               Aberdeen            1050.0
# 1                   Adna            1029.0
# 2              Anacortes            1149.0
# 3              Arlington            1140.0
# 4         Asotin-Anatone            1035.0
# 5                 Auburn             947.0
# 6             Bainbridge            1267.0
# 7          Battle Ground            1129.0
# 8               Bellevue            1273.0
# 9             Bellingham            1169.0
# 10                Bethel            1046.0
# 11             Bickleton               NaN
# 12                Blaine            1135.0
# 13             Bremerton            1024.0
# 14              Brewster             890.0
# 15            Bridgeport             932.0
# 16     Burlington-Edison             994.0
# 17                 Camas            1182.0
# 18         Cape Flattery            1028.0
# 19               Cascade            1057.0
# 20              Cashmere            1069.0
# ...
